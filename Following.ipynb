# %%
# Shortlist Follower Chart

from tikapi import TikAPI, ValidationException, ResponseException
from openpyxl import Workbook, load_workbook
from datetime import datetime, timedelta

# Initialize TikAPI
api = TikAPI("8mqoTQs1AXfSs6nskRCr5obvsWVytvQ1J0YPvIS1ylfEtl2D")
excel_file = "/Users/jw/Downloads/shortlist_data.xlsx"

shortlist = []


try:
    # Fetch the initial response
    response = api.public.followingList(
        secUid="MS4wLjABAAAAboanSl94WMrjvJtHejLumdRGgy9oYuygOQfbC-iVne34BIfjcygpqSH84qsh2XcT"
    )

    # Prepare the Excel file
    try:
        workbook = load_workbook(excel_file)
        sheet = workbook.active
    except FileNotFoundError:
        workbook = Workbook()
        sheet = workbook.active
        sheet.append(["Username", "Date", "Follower Count"])

    while response:
        # Extract relevant data
        data = response.json()
        user_list = data.get("userList", [])
        current_date = datetime.now().strftime("%Y-%m-%d")

        
        for user_data in user_list:
            username = user_data['user']['uniqueId']
            shortlist.append(username)
            follower_count = user_data['stats']['followerCount']
            sheet.append([username, current_date, follower_count])

        workbook.save(excel_file)

        # Check for the next cursor
        next_cursor = data.get("nextCursor")
        if not next_cursor:
            break

        print(f"Getting next items {next_cursor}")
        response = response.next_items()

    print(shortlist)

except ValidationException as e:
    print(e, e.field)

except ResponseException as e:
    print(e, e.response.status_code)


import pandas as pd

today = datetime.today().strftime('%m.%d.%y')

# Load the data
file_path = '/Users/jw/Downloads/shortlist_data.xlsx'  # Replace with your Excel file path
data = pd.read_excel(file_path)

# Sort the data to ensure it is ordered by Username and Date
data = data.sort_values(by=['Username', 'Date'])

# Calculate the Daily Difference
data['Daily Difference'] = data.groupby('Username')['Follower Count'].diff().fillna(0)

# Save the updated DataFrame to a new Excel file
output_file = f'/Users/jw/Downloads/shortlist_data_updated{today}.xlsx'
data.to_excel(output_file, index=False)

print(f"Updated file saved to: {output_file}")


import pandas as pd
from scipy.stats import linregress

today = datetime.today().strftime('%m.%d.%y')

def calculate_slopes_with_current_followers(input_file, output_file):
    # Load the data
    excel_data = pd.ExcelFile(input_file)
    sheet_name = excel_data.sheet_names[0]  # Assumes data is in the first sheet
    data = excel_data.parse(sheet_name)

    # Ensure 'Date' is in datetime format
    data['Date'] = pd.to_datetime(data['Date'])

    # Initialize a list to store results
    results = []

    # Group data by 'Username' and calculate the slope, current follower count, and average percent change
    for username, group in data.groupby('Username'):
        # Sort data by date to ensure proper order
        group = group.sort_values(by='Date')
        
        # Convert dates to ordinal numbers (x-axis)
        x = group['Date'].map(lambda date: date.toordinal())
        y = group['Follower Count']
        
        # Calculate slope if sufficient data points exist
        if len(group) > 1:
            slope, _, _, _, _ = linregress(x, y)
        else:
            slope = None  # Not enough data points
        
        # Calculate average percent change, excluding the first entry and handling invalid values
        pct_changes = group['Follower Count'].pct_change().dropna()
        valid_pct_changes = pct_changes[~pct_changes.isin([float('inf'), float('-inf')])]  # Exclude #DIV/0!
        avg_pct_change = valid_pct_changes.mean() if not valid_pct_changes.empty else None
        
        # Append results for each username
        results.append({
            'Username': username, 
            'Slope': slope, 
            'Average Percent Change': avg_pct_change
        })

    # Convert results to a DataFrame
    slope_data = pd.DataFrame(results)

    # Save the output to a new sheet in the same Excel file
    with pd.ExcelWriter(output_file, engine='openpyxl') as writer:
        # Write the original data
        data.to_excel(writer, index=False, sheet_name=sheet_name)
        # Write the slope results with average percent change
        slope_data.to_excel(writer, index=False, sheet_name='Slopes')

# Example usage
input_file = f'/Users/jw/Downloads/shortlist_data_updated{today}.xlsx'
output_file = f'/Users/jw/Downloads/shortlist_data_slope{today}.xlsx'
calculate_slopes_with_current_followers(input_file, output_file)

print('Done!')
# Out:
# Getting next items 1736456023
# Getting next items 1735836958
# Getting next items 1735788543
# Getting next items 1735403074
# Getting next items 1735176942
# Getting next items 1734972015
# Getting next items 1734927730
# Getting next items 1734750079
# Getting next items 1734651477
# Getting next items 1734635462
# Getting next items 1734282089
# Getting next items 1734140080
# Getting next items 1733931163
# Getting next items 1732036592
# ['jovi_greene_music', 'kierangardnermusic', 'guus_dielissen', 'tom.reagan', 'becomalley', 'brudibrothers', 'gregorhuntercoleman', 'jameswimbleymusic', 'eileenalister', 'chaninmusicc', 'ashleyannemusic', 'ryanmackmusic', 'cimorelliband', 'katielynnesharbaugh', 'bowanderson', 'jamesmarriott', 'oliviakanaan', 'riccipaolomusic', 'aiyanaleeonthetrack', 'ethangandermusic', 'bethhartmusic', 'bex.cd', 'thefrankfoster', 'avadellapietramusic', 'itsonlysadiee', 'sina.theofficial', 'nicolinabozzo', 'whotfisarya', 'sarakaysmusic', 'rylan_fisch', 'thezmanexperience', 'bengemusic', 'thatsdax', 'iamactuallyjakehill', 'grahambarham', 'lilyrosemusicofficial', 'dylanmarlowemusic', 'kylerstevenfisher', 'oliveranthonymusic', 'restlessroad', 'jonlangston', 'tigirlilygold', 'gabe.jackson_music', 'talanmcguiremusic', 'frankiewhitemusic', 'sophunky', 'ozzyhigleymusic', 'ellajanemusic', 'markambor', 'sierracarsonmusic', 'ryankindermusic', 'allysalort', 'arcydrive', 'seanbiopcik', 'thebenrodrigues', 'mylessmithuk', 'alexsampson', 'kyle_jenk', '_mackmartin_', 'willcullenofficial', 'jaybenzmusic', 'cadenmcguire', 'musogabi', 'soph1eg1bson', 'garethmusic', 'jack.aaustin', 'adamsimonsmusic', 'alexrvphillips', 'carleynunndavis', 'caioklin_', 'sierrasikoramusic', 'max_flinn', 'philipbowenmusic', 'juliacolemusic', 'ashleyryanmusic', 'mackgresham', 'jaredbenjaminofficial', 'tayloracorn1', 'jadelemac', 'alessirose', 'spritelynotthesoda', 'worldsinred', 'panoramicband', 'caden.cookus', 'benjohansen0', 'mercerhenderson', 'ellirowe', 'elenasidiro', 'officialpaperrose', 'chandaddy69', 'lydia.kenny', 'muninorodom', 'lauren_mascitti_music', 'brokenrecord.band', 'shayasmusic', 'alangogoll', 'jacksoncafferty', 'bradenbales', 'kevinatwatermusic', 'natalielaynemusic', 'jquimbymusic', 'emilee.moore', 'ryan.larkins', 'travisdenning', 'davis_brothers_band', 'owenpiehl', 'joejordan_music', 'theswichband', 'timmymckeevermusic', 'alexcolesofficial', 'annagravesmusic', 'pipermadison', '19miles_per_hour', 'daydreamers_uk', 'conallcafferty', 'itsaronofficial', 'gabe.quinnn', 'immaoger', 'braden_jamison', 'will.swinton', 'grant_martini', 'leahllawson', 'jacksonchasemusic', 'chaislynmusic', 'jimmycliftonmusic', 'claytonnileyoung', 'theselacampbell', 'ethanrburdick', 'jennybakermusic', 'nikomoon', 'willbanistermusic', 'willmoseleymusic', 'noah._.jamez', 'iamdeyaz', 'courtneyhadwin', 'mackenzy.mackay', 'the_cherrybombss', 'iamkodiwilliams', 'mjayeee7_', 'ameliekalia', 'carterryanmusic', 'loganryanband', 'treylewismusic', 'claypagemusic', 'brendanwaltermusic', 'gracchusofficial', 'josieedwardsmusic', 'cooperalbrightmusic', 'billystringsofficial', 'greylanjames', 'traygoochmusic', 'anthony_gargiula', 'kaelanfromearth', 'gltitus', 'landonsmithmusic', 'thebyrnebrothers', 'gracetylermusic', 'red_ridge_music', 'yuatsmusic', 'elias_hix', 'officialmissvelvet', 'yourmomsbestfriendband1', 'rae_stringz', 'hunterrootmusic', 'martinefarstad', 'elipattersonsongs', 'claytonmannmusic', 'maddoxbatson', 'loganmacmusic', 'alexmakesadsongs', 'draytonfarleymusic', 'taylersmusic', 'rickychiltonmusic', 'gabrielabee', 'alexlambertmusic', 'calebhearnmusic', 'gianazaffinomusic', 'chloeisabellamusic', 'annaraemusic', 'ishiver', 'edsimmons_music', 'adammelchor', 'vincentlimamusic', 'wheelwrightphx', 'andrew.brozek.music', 'ferestermusic', 'keannamag', 'morgan_moyer', 'georgebirgeofficial', 'zachbeeken', 'raffaelmarques_', 'demchukmusic', 'jamesbakian', 'jadafacer', 'marcscibilia', 'nellmescal', 'cuffingseasonmusic', 'jeorgia.rose', 'reubenmedlin', 'evechristina', 'annajmusic', 'niallmcnamee', 'thepresleybarker', 'mackenzieporter', 'needtobreathe', '_luke.the.voice_', 'oldhickorymusic', 'iamnicd', 'colton_mortensen', 'johnmorganmusic', 'themakaylarenee', 'hi_itsbennie', '_kenzieharris_', 'averybouch', 'erinkinseytx', 'siennaspiro', 'nathancoxmusic', 'diehardcowboy_', '_jaywebbmusic', 'bryanandrewsmusic', 'millingtontheband', 'samdonaldmusic', 'thecalebmills', 'weskomusic', 'franthesinger', 'cooperalan1', 'kelseab ...
# Updated file saved to: /Users/jw/Downloads/shortlist_data_updated01.14.25.xlsx
# Done!
